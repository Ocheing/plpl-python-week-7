# %% [markdown]
# Load and Explore the Dataset

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# Load Iris dataset from sklearn
try:
    iris = load_iris()
    # Create DataFrame with feature names
    df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
    # Add species as categorical labels
    df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)
    print("✅ Dataset loaded successfully.")
except Exception as e:
    print("❌ Error loading dataset:", e)
    df = None

# Proceed only if data loaded
if df is not None:
    # Display first few rows
    print("\n📊 First 5 rows of the dataset:")
    print(df.head())

    # Check data types and missing values
    print("\n📋 Dataset info:")
    print(df.info())

    print("\n🔍 Missing values in each column:")
    print(df.isnull().sum())

    # Optional: Summary statistics
    print("\n📈 Summary statistics:")
    print(df.describe())

    # Optional: Plot pairplot to visualize distributions
    sns.set(style="whitegrid")
    sns.pairplot(df, hue="species", corner=True)
    plt.suptitle("Pairwise Feature Plots of Iris Dataset", y=1.02)
    plt.show()

    # Note: No missing values to clean, but examples are provided below:
    # df.dropna(inplace=True)  # Drop rows with missing values
    # df.fillna(method='ffill', inplace=True)  # Fill missing values forward
# Out:
# ✅ Dataset loaded successfully.
#
# 📊 First 5 rows of the dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
#
# 📋 Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
# ...

# %% [markdown]
# Load and Explore the Dataset

# %%
# Basic statistics
print("\nDescriptive Statistics:\n", df.describe())

# Group by species and get mean of each feature
grouped = df.groupby('species').mean()
print("\nMean of Features by Species:\n", grouped)

# Identify patterns
print("\nObservation:")
print("→ Versicolor seems to have intermediate values across features.")
print("→ Virginica generally has the largest petal and sepal measurements.")
# Out:
# Descriptive Statistics:
#         sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
#
# Mean of Features by Species:
#              sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# ...

# %% [markdown]
# STEP 3. Data Visualization

# %% [markdown]
# 1. Line Chart – Mean petal length by species (simulating trend over a category)

# %%
grouped['petal length (cm)'].plot(kind='line', marker='o')
plt.title('Mean Petal Length per Species')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# 2. Bar Chart – Average petal length per species

# %%
grouped['petal length (cm)'].plot(kind='bar', color='skyblue')
plt.title('Average Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Histogram – Distribution of sepal length

# %%
plt.hist(df['sepal length (cm)'], bins=20, color='green', edgecolor='black')
plt.title('Distribution of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 4. Scatter Plot – Sepal length vs. petal length

# %%
sns.scatterplot(data=df, x='sepal length (cm)', y='petal length (cm)', hue='species')
plt.title('Sepal Length vs Petal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.legend()
plt.show()

# %%
# !pip install pandas matplotlib seaborn scikit-learn

# %%
import sys
# !{sys.executable} -m pip install pandas

# %%
# !pip install matplotlib
